# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers

# %%
from tensorflow.keras.models import load_model
model = load_model('../model_saved/b_tag_model.h5')
# Out:
# 2023-05-19 06:08:27.212404: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/sft.cern.ch/lcg/releases/MCGenerators/thepeg/2.2.3-88592/x86_64-centos7-gcc8-opt/lib/ThePEG:/cvmfs/sft.cern.ch/lcg/releases/MCGenerators/herwig++/7.2.3-35f7a/x86_64-centos7-gcc8-opt/lib/Herwig:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/jaxlib/mlir/_mlir_libs:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/torch/lib:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/onnxruntime/capi/:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/contrib/tensor_forest:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages/tensorflow/python/framework:/cvmfs/sft.cern.ch/lcg/releases/java/8u312-80070/x86_64-centos7-gcc8-opt/jre/lib/amd64:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib64:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib:/cvmfs/sft.cern.ch/lcg/releases/gcc/8.3.0-cebb0/x86_64-centos7/lib64:/cvmfs/sft.cern.ch/lcg/releases/binutils/2.30-e5b21/x86_64-centos7/lib:/cvmfs/sft.cern.ch/lcg/releases/R/4.1.2-234e4/x86_64-centos7-gcc8-opt/lib64/R/library/readr/rcon:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/extras/CUPTI/lib64:/cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/targets/x86_64-linux/lib
# 2023-05-19 06:08:27.212466: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
import hls4ml
import os
os.environ['PATH'] = '/opt/Xilinx/Vivado/2020.1/bin:' + os.environ['PATH']

# %%
# %%capture

int_bit = 10
i = 10
reuse = 4
precision = 'ap_fixed<{},{}>'.format((int_bit+i), int_bit)
fix_int_precision = 'ap_fixed<{},{}>'.format((16+i), 14)
dirc = 'runs/B_tagging_run/r4_{}int_{}frac'.format(int_bit, i)
#First, the baseline model
hls_config = hls4ml.utils.config_from_keras_model(model, granularity='name')

# Set the precision and reuse factor for the full model
hls_config['Model']['Precision'] = precision
hls_config['Model']['ReuseFactor'] = reuse
hls_config['Model']['Strategy'] = 'Resource'

for Layer in hls_config['LayerName'].keys():
    hls_config['LayerName'][Layer]['Precision'] = precision
    hls_config['LayerName'][Layer]['Strategy'] = 'Resource'
    hls_config['LayerName'][Layer]['ReuseFactor'] = reuse
    hls_config['LayerName'][Layer]['weight'] = precision
    hls_config['LayerName'][Layer]['scale'] = precision
    hls_config['LayerName'][Layer]['bias'] = precision
    hls_config['LayerName'][Layer]['accum_t'] = fix_int_precision
    if 'multi_head_attention' in Layer:
        hls_config['LayerName'][Layer]['table_t'] = fix_int_precision
        hls_config['LayerName'][Layer]['inv_range'] = 256
        hls_config['LayerName'][Layer]['exp_range'] = 4
        hls_config['LayerName'][Layer]['table_size'] = 1024
    if 'dense' in Layer:
        hls_config['LayerName'][Layer]['table_t'] = fix_int_precision
        hls_config['LayerName'][Layer]['inv_range'] = 256
        hls_config['LayerName'][Layer]['table_size'] = 1024
        hls_config['LayerName'][Layer]['exp_range'] = 4

cfg = hls4ml.converters.create_config(backend='Vivado')
cfg['IOType']     = 'io_parallel' # Must set this if using CNNs!
cfg['HLSConfig']  = hls_config
cfg['KerasModel'] = model
cfg['OutputDir']  = dirc
cfg['Part'] = 'xcvu13p-fhga2104-2L-e'

hls_model = hls4ml.converters.keras_to_hls(cfg)
hls_model.compile()
hls_model.build(csim=False, synth=True, vsynth=True)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: Applying HLS Y2K22 patch v1.2 for IP revision
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'zhjiang' on host 'olivb-16.cern.ch' (Linux_x86_64 version 3.10.0-1160.88.1.el7.x86_64) on Fri May 19 06:08:45 CEST 2023
# INFO: [HLS 200-10] In directory '/data/hlssynt-users/zhjiang/runs/B_tagging_run/r2_10int_10frac'
# WARNING: [HLS 200-40] Environment variable 'C_INCLUDE_PATH' is set to /cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/include.
# WARNING: [HLS 200-40] Environment variable 'CPLUS_INCLUDE_PATH' is set to /cvmfs/sft.cern.ch/lcg/views/LCG_102cuda/x86_64-centos7-gcc8-opt/include.
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/data/hlssynt-users/zhjiang/runs/B_tagging_run/r2_10int_10frac/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/data/hlssynt-users/zhjiang/runs/B_tagging_run/r2_10int_10frac/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 60.
# INFO: [HLS 200-10] Setting target device to 'xcvu13p-fhga2104-2L-e'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/nnet_utils/nnet_multiheadattention.h:308:2
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/nnet_utils/nnet_multiheadattention.h:312:2
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/nnet_utils/nnet_multiheadattention.h:318:5
# WARNING: [HLS 214-167] There are a total of 5 such instances of non-canonical statements in the dataflow region: firmware/nnet_utils/nnet_multiheadattention.h:289:2
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:85
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:111
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:135
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:148
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:159
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:174
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:187
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:95:202
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:103:67
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:103:71
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:111:67
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:111:71
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:92
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:118
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:142
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:155
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:166
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:181
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:194
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:119:209
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:127:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:127:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:135:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:135:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:98
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:125
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:150
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:164
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:176
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:192
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:206
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:143:222
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:151:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:151:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:159:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:159:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:167:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:167:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:175:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:175:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:183:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:183:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:191:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:191:77
# WARNING: [HLS 200-471] Dataflow form checks found 48 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:55 ; elapsed = 00:00:58 . Memory (MB): peak = 1630.246 ; gain = 1103.887 ; free physical = 35602 ; free virtual = 77288
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:55 ; elapsed = 00:00:58 . Memory (MB): peak = 1630.246 ; gain = 1103.887 ; free physical = 35601 ; free virtual = 77288
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:135).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:83).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:135).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:83).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' (firmware/nnet_utils/nnet_dense_latency.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:135).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::limit' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:83).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:163).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:107).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:163).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:107).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' (firmware/nnet_utils/nnet_dense_latency.h:63).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:163).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:107).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' (firmware/nnet_utils/nnet_dense_resource.h:77).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:222).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:221).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:220).
# INFO: [XFORM 203-603] Inlining function 'nnet::softmax<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config2>' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:112).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' into 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'myproject' (firmware/myproject.cpp:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' into 'myproject' (firmware/myproject.cpp:111).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:222).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:221).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:220).
# INFO: [XFORM 203-603] Inlining function 'nnet::softmax<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config9>' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:112).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' into 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' into 'myproject' (firmware/myproject.cpp:127).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'myproject' (firmware/myproject.cpp:135).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:222).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:221).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:220).
# INFO: [XFORM 203-603] Inlining function 'nnet::softmax<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config16>' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:112).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' into 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' into 'myproject' (firmware/myproject.cpp:151).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_seq<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' into 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' (firmware/nnet_utils/nnet_dense.h:47).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' into 'myproject' (firmware/myproject.cpp:159).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' into 'myproject' (firmware/myproject.cpp:167).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' into 'myproject' (firmware/myproject.cpp:175).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' into 'myproject' (firmware/myproject.cpp:183).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' (firmware/nnet_utils/nnet_dense_resource.h:276).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' into 'myproject' (firmware/myproject.cpp:191).
# INFO: [XFORM 203-603] Inlining function 'nnet::softmax<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config31>' into 'myproject' (firmware/myproject.cpp:193).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:01:20 ; elapsed = 00:01:24 . Memory (MB): peak = 1630.246 ; gain = 1103.887 ; free physical = 35182 ; free virtual = 76929
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::mantissa' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.1/continuous/2020_05_27_2902540/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:15) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::expv' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.1/continuous/2020_05_27_2902540/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:18) automatically.
# INFO: [XFORM 203-602] Inlining function 'fp_struct<double>::__signbit' into 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' (/wrk/2020.1/continuous/2020_05_27_2902540/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:59) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, (ap_q_mode)6, double>' into 'generic_cast_IEEE754<int, double>' (/wrk/2020.1/continuous/2020_05_27_2902540/src/products/hls/hls_lib/hlsmath/include/FloatingPoint/hls_case_IEEE754.h:117) automatically.
# INFO: [XFORM 203-602] Inlining function 'generic_cast_IEEE754<int, double>' into '__hls_fptosi_double_i32' (/wrk/2020.1/continuous/2020_05_27_2902540/src/products/hls/hls_lib/hlsmath/src/lib_floatconversion.cpp:55) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::read_stream_array<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 6>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:217) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:82) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_multiheadattention.h:134) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_2>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config4>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_1>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::read_stream_array<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 6>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:217) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:82) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>' (firmware/nnet_utils/nnet_multiheadattention.h:134) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9_2>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config11>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_1>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::read_stream_array<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 6>' into 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:217) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:82) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>' (firmware/nnet_utils/nnet_multiheadattention.h:134) automatically.
# INFO: [XFORM 203-602] Inlining function '__hls_fptosi_double_i32' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' (firmware/nnet_utils/nnet_dense_latency.h:55) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' into 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16_2>' (firmware/nnet_utils/nnet_dense_latency.h:83) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config20>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' into 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>' (firmware/nnet_utils/nnet_dense_resource.h:100->firmware/nnet_utils/nnet_dense_resource.h:276) automatically.
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:01:50 ; elapsed = 00:01:54 . Memory (MB): peak = 1630.246 ; gain = 1103.887 ; free physical = 35063 ; free virtual = 76820
# WARNING: [XFORM 203-1102] Ignored multiple data pack pragma for variable 'v_proj.V.data.V' (firmware/nnet_utils/nnet_multiheadattention.h:293).
# INFO: [XFORM 203-1101] Packing variable 'v_proj.V.data.V' (firmware/nnet_utils/nnet_multiheadattention.h:293) into a 640-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'datav_pack.data.V' (firmware/nnet_utils/nnet_multiheadattention.h:131) into a 640-bit variable.
# ...
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0' by setting 'weights[383].V' to 'key_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1' by setting 'weights[383].V' to 'query_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2' by setting 'weights[383].V' to 'value_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0' by setting 'weights[383].V' to 'key_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1' by setting 'weights[383].V' to 'query_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2' by setting 'weights[383].V' to 'value_weight2.V.383'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2.0' by setting 'biases[0].V' to 'value_bias2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.2.0' by setting 'biases[0].V' to 'value_bias2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1.0' by setting 'biases[0].V' to 'query_bias2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.1.0' by setting 'biases[0].V' to 'query_bias2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0.0' by setting 'biases[0].V' to 'key_bias2.V.0'.
# INFO: [XFORM 203-622] Instantiating function 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0'(firmware/nnet_utils/nnet_dense_latency.h:35:1) to 'nnet::dense_latency<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_1>.0.0' by setting 'biases[0].V' to 'key_bias2.V.0'.
# INFO: [XFORM 203-721] Changing loop 'Loop_1_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-721] Changing loop 'Loop_2_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-721] Changing loop 'Loop_3_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-721] Changing loop 'Loop_4_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-721] Changing loop 'Loop_5_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-721] Changing loop 'Loop_6_proc' (firmware/nnet_utils/nnet_dense_seq.h:34) to a process function for dataflow in function 'myproject'.
# INFO: [XFORM 203-712] Applying dataflow to function 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>', detected/extracted 12 process function(s):
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>.entry97579883'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>643'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>644'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>645'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>646'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>647'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>648'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>649'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>650'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>651'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>652'
# 	 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'.
# INFO: [XFORM 203-712] Applying dataflow to function 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>', detected/extracted 12 process function(s):
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>.entry97639885'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>653'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>654'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>655'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>656'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>657'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>658'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>659'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>660'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>661'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>662'
# 	 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>'.
# INFO: [XFORM 203-712] Applying dataflow to function 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>', detected/extracted 12 process function(s):
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>.entry97699887'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>663'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>664'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>665'
# 	 'nnet::data_prep<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>666'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>667'
# 	 'nnet::lin_projection<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>668'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>669'
# 	 'nnet::matrixmul_transpose<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>670'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>671'
# 	 'nnet::matrixmul<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>672'
# 	 'nnet::dense_out<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>'.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject', detected/extracted 26 process function(s):
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config3>'
# 	 'Loop_1_proc'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config5>'
# 	 'Loop_2_proc'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>'
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config9>'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config10>'
# 	 'Loop_3_proc'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config12>'
# 	 'Loop_4_proc'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config15>'
# 	 'nnet::multiheadattention<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config16>'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config17>'
# 	 'Loop_5_proc'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config19>'
# 	 'Loop_6_proc'
# 	 'nnet::add<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config22>'
# 	 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config24>'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config25>'
# 	 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config27>'
# 	 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config28>'
# 	 'nnet::relu<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, relu_config29>'
# 	 'nnet::dense_resource<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config30>'
# 	 'nnet::softmax_legacy<ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config31>'.
